# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset
df = pd.read_csv('account.csv')

df.shape
# Out:
# (6, 4)

# %%
df.isnull().sum()
# Out:
# account_number    0
# account_name      0
# account_type      0
# currency          0
# dtype: int64
